# %%
import pandas as pd
pd.options.display.max_colwidth = 10000
df = pd.read_csv('/Users/user/Downloads/el_universal.csv', sep='|')
df
# Out:
#                                                                                                                                     URL  \
# 0                                    http://www.eluniversal.com.mx/articulo/cartera/telecom/2017/02/13/facebook-quiere-su-propio-tinder
# 1                                    http://www.eluniversal.com.mx/articulo/cartera/telecom/2017/02/13/facebook-quiere-su-propio-tinder
# 2                                    http://www.eluniversal.com.mx/articulo/cartera/telecom/2017/02/13/facebook-quiere-su-propio-tinder
# 3                                    http://www.eluniversal.com.mx/articulo/cartera/telecom/2017/02/13/facebook-quiere-su-propio-tinder
# 4                                    http://www.eluniversal.com.mx/articulo/cartera/telecom/2017/02/13/facebook-quiere-su-propio-tinder
# 5                                    http://www.eluniversal.com.mx/articulo/cartera/telecom/2017/02/13/facebook-quiere-su-propio-tinder
# ...

# %%
df['sents'][130]
# Out:
# 'HRW aseguró que "el patrón" de estos ataques "muestra que se coordinaron con la estrategia militar global para recuperar Alepo" y que no fueron obra de elementos aislados del Ejército, por lo que urgió al Consejo de Seguridad de la ONU a imponer sanciones contra Damasco.'
